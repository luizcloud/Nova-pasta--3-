# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Space X  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ## Web scraping Falcon 9 and Falcon Heavy Launches Records from Wikipedia

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# In this lab, you will be performing web scraping to collect Falcon 9 historical launch records from a Wikipedia page titled `List of Falcon 9 and Falcon Heavy launches`
#
# https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_1_L2/images/Falcon9_rocket_family.svg)

# %% [markdown]
# Falcon 9 first stage will land successfully

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/landing_1.gif)

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/crash.gif)

# %% [markdown]
# More specifically, the launch records are stored in a HTML table shown below:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_1_L2/images/falcon9-launches-wiki.png)

# %% [markdown]
#   ## Objectives
# Web scrap Falcon 9 launch records with `BeautifulSoup`:
# - Extract a Falcon 9 launch records HTML table from Wikipedia
# - Parse the table and convert it into a Pandas data frame

# %% [markdown]
# First let's import required packages for this lab

# %%
# !pip3 install beautifulsoup4
# !pip3 install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\luiz felix\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\luiz felix\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from beautifulsoup4) (2.5)
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: C:\Users\Luiz Felix\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: requests in c:\users\luiz felix\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\luiz felix\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luiz felix\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\luiz felix\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luiz felix\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (2023.5.7)
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: C:\Users\Luiz Felix\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import sys

import requests
from bs4 import BeautifulSoup
import re
import unicodedata
import pandas as pd

# %% [markdown]
# and we will provide some helper functions for you to process web scraped HTML table

# %%
def date_time(table_cells):
    """
    This function returns the data and time from the HTML  table cell
    Input: the  element of a table data cell extracts extra row
    """
    return [data_time.strip() for data_time in list(table_cells.strings)][0:2]

def booster_version(table_cells):
    """
    This function returns the booster version from the HTML  table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=''.join([booster_version for i,booster_version in enumerate( table_cells.strings) if i%2==0][0:-1])
    return out

def landing_status(table_cells):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=[i for i in table_cells.strings][0]
    return out


def get_mass(table_cells):
    mass=unicodedata.normalize("NFKD", table_cells.text).strip()
    if mass:
        mass.find("kg")
        new_mass=mass[0:mass.find("kg")+2]
    else:
        new_mass=0
    return new_mass


def extract_column_from_header(row):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    if (row.br):
        row.br.extract()
    if row.a:
        row.a.extract()
    if row.sup:
        row.sup.extract()
        
    colunm_name = ' '.join(row.contents)
    
    # Filter the digit and empty names
    if not(colunm_name.strip().isdigit()):
        colunm_name = colunm_name.strip()
        return colunm_name

# %% [markdown]
# To keep the lab tasks consistent, you will be asked to scrape the data from a snapshot of the  `List of Falcon 9 and Falcon Heavy launches` Wikipage updated on
# `9th June 2021`

# %%
static_url = "https://en.wikipedia.org/w/index.php?title=List_of_Falcon_9_and_Falcon_Heavy_launches&oldid=1027686922"

# %% [markdown]
# Next, request the HTML page from the above URL and get a `response` object

# %% [markdown]
# ### TASK 1: Request the Falcon9 Launch Wiki page from its URL

# %% [markdown]
# First, let's perform an HTTP GET method to request the Falcon9 Launch HTML page, as an HTTP response.

# %%
# use requests.get() method with the provided static_url
# assign the response to a object
# URL da página da Wikipedia
static_url = "https://en.wikipedia.org/w/index.php?title=List_of_Falcon_9_and_Falcon_Heavy_launches"

# Realizar uma solicitação HTTP GET para obter a página HTML
response = requests.get(static_url)

# Verificar o código de status da resposta
print("Status Code:", response.status_code)
# Out:
# Status Code: 200

# %% [markdown]
# Create a `BeautifulSoup` object from the HTML `response`

# %%
# Use BeautifulSoup() to create a BeautifulSoup object from a response text content
soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# Print the page title to verify if the `BeautifulSoup` object was created properly

# %%
# Use soup.title attribute
print(soup.title)
# Out:
# <title>List of Falcon 9 and Falcon Heavy launches - Wikipedia</title>

# %% [markdown]
# ### TASK 2: Extract all column/variable names from the HTML table header

# %% [markdown]
# Next, we want to collect all relevant column names from the HTML table header

# %% [markdown]
# Let's try to find all tables on the wiki page first. If you need to refresh your memory about `BeautifulSoup`, please check the external reference link towards the end of this lab

# %%
# Use the find_all function in the BeautifulSoup object, with element type `table`
# Assign the result to a list called `html_tables`
html_tables = soup.find_all('table')

# %% [markdown]
# Starting from the third table is our target table contains the actual launch records.

# %%
# Let's print the third table and check its content
first_launch_table = html_tables[2]
print(first_launch_table)
# Out:
# <table class="wikitable" style="width:100%; font-size:1.00em; line-height:1.5em;">
# <tbody><tr class="is-sticky">
# <th scope="col" style="width: 10%;">Date and time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>booster</a><sup class="reference" id="cite_ref-booster_25-2"><a href="#cite_note-booster-25">[c]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_26-2"><a href="#cite_note-Dragon-26">[d]</a></sup>
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th></tr>
# <tr>
# <td rowspan="2">18 April 2024<br/>~22:40<sup class="reference" id="cite_ref-nextSFupcoming_340-1"><a href="#cite_note-nextSFupcoming-340">[331]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCSFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/Starlink" title="Starlink">Starlink Group 6-52</a> (~23 satellites)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td></tr>
# <tr>
# <td colspan="5">An East Coast v2 mini Starlink launch to their Generation 2 network.
# </td></tr>
# <tr>
# <td rowspan="2">22 April 2024<br/>~22:40<sup class="reference" id="cite_ref-nextSFupcoming_340-2"><a href="#cite_note-nextSFupcoming-340">[331]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCSFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/Starlink" title="Starlink">Starlink Group 6-53</a> (~23 satellites)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td></tr>
# <tr>
# <td colspan="5">An East Coast v2 mini Starlink launch to their Generation 2 network.
# </td></tr>
# <tr>
# <td rowspan="2">28 April 2024<sup class="reference" id="cite_ref-Galileo_341-0"><a href="#cite_note-Galileo-341">[332]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">KSC</a>,<br/><a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/Galileo_(satellite_navigation)" title="Galileo (satellite navigation)">Galileo</a>-L12 (2 Satellites)
# </td>
# <td><a class="mw-redirect" href="/wiki/Medium_Earth_Orbit" title="Medium Earth Orbit">MEO</a>
# </td>
# <td><a href="/wiki/European_Space_Agency" title="European Space Agency">ESA</a>
# </td></tr>
# <tr>
# <td colspan="5">First Galileo satellites booked on a US rocket following delays to the European <a href="/wiki/Ariane_6" title="Ariane 6">Ariane 6</a> program.
# </td></tr>
# <tr>
# <td rowspan="2">April 2024<sup class="reference" id="cite_ref-nextSFupcoming_340-3"><a href="#cite_note-nextSFupcoming-340">[331]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a> ♺
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a href="/wiki/DigitalGlobe#WorldView_Legion" title="DigitalGlobe">WorldView Legion 1 &amp; 2</a> Mission 1 (2 satellites)<sup class="reference" id="cite_ref-worldviewlegion_342-0"><a href="#cite_note-worldviewlegion-342">[333]</a></sup>
# </td>
# <td><a href="/wiki/Sun-synchronous_orbit" title="Sun-synchronous orbit">SSO</a>
# </td>
# <td><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">Maxar Technologies</a>
# </td></tr>
# <tr>
# <td colspan="5">Two <a href="/wiki/Maxar_Technologies" title="Maxar Technologies">Maxar Technologies</a> satellites built by subsidiary <a href="/wiki/SSL_(company)" title="SSL (company)">SSL</a> for subsidiary <a href="/wiki/DigitalGlobe" title="DigitalGlobe">DigitalGlobe</a>.<sup class="reference" id="cite_ref-worldviewlegion_342-1"><a href="#cite_note-worldviewlegion-342">[333]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">May 2024<sup class="reference" id="cite_ref-343"><a href="#cite_note-343">[334]</a></sup><sup class="reference" id="cite_ref-344"><a href="#cite_note-344">[335]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a> or <a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>
# </td>
# <td><a href="/wiki/EarthCARE" title="EarthCARE">EarthCARE</a><sup class="reference" id="cite_ref-345"><a href="#cite_note-345">[336]</a></sup>
# </td>
# <td>
# </td>
# <td><a class="mw-redirect" href="/wiki/ESA" title="ESA">ESA</a>
# </td></tr>
# <tr>
# <td colspan="5">EarthCARE (Cloud, Aerosol and Radiation Explorer) satellite is the sixth mission in ESA's Earth Explorer program and it aims to advance our understanding of the role clouds and aerosols play in reflecting incident solar radiation back into space and trapping infrared radiation emitted from Earth's surface.
# </td></tr>
# <tr>
# <td rowspan="4">25 June 2024<sup class="reference" id="cite_ref-346"><a href="#cite_note-346">[337]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_Heavy" title="Falcon Heavy">Falcon Heavy B5</a><br/><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1087" title="List of Falcon 9 first-stage boosters">B1087 (core)</a>
# </td>
# <td rowspan="3"><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">KSC</a>,<br/><a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td rowspan="3"><a href="/wiki/GOES-U" title="GOES-U">GOES-U</a><sup class="reference" id="cite_ref-347"><a href="#cite_note-347">[338]</a></sup>
# </td>
# <td rowspan="3"><a href="/wiki/Geostationary_orbit" title="Geostationary orbit">GEO</a>
# </td>
# <td rowspan="3"><a class="mw-redirect" href="/wiki/NOAA" title="NOAA">NOAA</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1072" title="List of Falcon 9 first-stage boosters">B1072.1 (side)</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1086" title="List of Falcon 9 first-stage boosters">B1086.1 (side)</a>
# </td></tr>
# <tr>
# <td colspan="5">In September 2021, NASA awarded SpaceX a $152.5 million contract to provide launch services for the <a href="/wiki/GOES-U" title="GOES-U">GOES-U</a> weather satellite.
# </td></tr>
# <tr>
# <td rowspan="2">June 2024<sup class="reference" id="cite_ref-348"><a href="#cite_note-348">[339]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/PT_Pasifik_Satelit_Nusantara#Nusantara_Lima" title="PT Pasifik Satelit Nusantara">Nusantara Lima</a><sup class="reference" id="cite_ref-349"><a href="#cite_note-349">[340]</a></sup>
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>?
# </td>
# <td><a href="/wiki/PT_Pasifik_Satelit_Nusantara" title="PT Pasifik Satelit Nusantara">PT Pasifik Satelit Nusantara</a>
# </td></tr>
# <tr>
# <td colspan="5">A hot backup system for <a href="/wiki/PT_Pasifik_Satelit_Nusantara#SATRIA-1" title="PT Pasifik Satelit Nusantara">SATRIA-1</a>.<sup class="reference" id="cite_ref-350"><a href="#cite_note-350">[341]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">June 2024<sup class="reference" id="cite_ref-351"><a href="#cite_note-351">[342]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a> / <a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/SpaceX_CRS-31" title="SpaceX CRS-31">SpaceX CRS-31</a><sup class="reference" id="cite_ref-March2022CRS2_320-1"><a href="#cite_note-March2022CRS2-320">[311]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td></tr>
# <tr>
# <td colspan="5">Six additional <a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS-2</a> missions for Dragon 2 were announced in March 2022, resupplying the ISS until 2026.
# </td></tr>
# <tr>
# <td rowspan="2">Q2 2024<sup class="reference" id="cite_ref-Rainbow_352-0"><a href="#cite_note-Rainbow-352">[343]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a> or <a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>
# </td>
# <td>BlueBird Block 1 (5 Satellites)<sup class="reference" id="cite_ref-AST_SpaceMobile_delays_commercial_s_353-0"><a href="#cite_note-AST_SpaceMobile_delays_commercial_s-353">[344]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/AST_SpaceMobile" title="AST SpaceMobile">AST SpaceMobile</a>
# </td></tr>
# <tr>
# <td colspan="5">Cellphone-compatible broadband constellation. Each satellite is to be a similar size and weight to its 1,500-kilogram BlueWalker 3 prototype and have a 64 square meter phased array antenna.
# </td></tr>
# <tr>
# <td rowspan="2">Q2 2024<sup class="reference" id="cite_ref-sn-20240102_354-0"><a href="#cite_note-sn-20240102-354">[345]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/GSAT-20" title="GSAT-20">GSAT-20</a><sup class="reference" id="cite_ref-NSIL_355-0"><a href="#cite_note-NSIL-355">[346]</a></sup> (CMS-03)
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/New_Space_India_Limited" title="New Space India Limited">New Space India Limited</a><sup class="reference" id="cite_ref-NSIL_355-1"><a href="#cite_note-NSIL-355">[346]</a></sup><br/><a href="/wiki/Dish_TV" title="Dish TV">Dish TV</a><sup class="reference" id="cite_ref-356"><a href="#cite_note-356">[347]</a></sup>
# </td></tr>
# <tr>
# <td colspan="5">Indian telecommunications satellite for <a href="/wiki/Dish_TV" title="Dish TV">Dish TV</a>. Originally planned to launch on <a href="/wiki/ISRO" title="ISRO">ISRO</a>'s <a href="/wiki/LVM3" title="LVM3">LVM3</a>,<sup class="reference" id="cite_ref-annualreport2018_357-0"><a href="#cite_note-annualreport2018-357">[348]</a></sup> but later shifted to <a href="/wiki/Falcon_9" title="Falcon 9">Falcon 9</a> due to mass and scheduling issues.<sup class="reference" id="cite_ref-sn-20240102_354-1"><a href="#cite_note-sn-20240102-354">[345]</a></sup> It will be the first ISRO-made satellite to move from <a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">geostationary transfer orbit</a> to <a href="/wiki/Geosynchronous_orbit" title="Geosynchronous orbit">geosynchronous orbit</a> using electric propulsion.<sup class="reference" id="cite_ref-thewire_358-0"><a href="#cite_note-thewire-358">[349]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">H1 2024<sup class="reference" id="cite_ref-nextSFupcoming_340-4"><a href="#cite_note-nextSFupcoming-340">[331]</a></sup><sup class="reference" id="cite_ref-SFPR9321_359-0"><a href="#cite_note-SFPR9321-359">[350]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a><sup class="reference" id="cite_ref-ussf36config_360-0"><a href="#cite_note-ussf36config-360">[351]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td>NROL-69
# </td>
# <td class="no table-no2" data-sort-value="" style="background: #DDF; vertical-align: middle; text-align: center;"><abbr title="To be announced">TBA</abbr>
# </td>
# <td><a href="/wiki/United_States_Space_Force" title="United States Space Force">USSF</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2021.<sup class="reference" id="cite_ref-defense.gov_361-0"><a href="#cite_note-defense.gov-361">[352]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">Mid 2024<sup class="reference" id="cite_ref-362"><a href="#cite_note-362">[353]</a></sup><sup class="reference" id="cite_ref-363"><a href="#cite_note-363">[354]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/Astranis" title="Astranis">MicroGEO</a> (4 satellites)<sup class="reference" id="cite_ref-astranis-microgeo-f9_364-0"><a href="#cite_note-astranis-microgeo-f9-364">[355]</a></sup>
# </td>
# <td><a href="/wiki/Geostationary_orbit" title="Geostationary orbit">GEO</a>
# </td>
# <td><a href="/wiki/Astranis" title="Astranis">Astranis</a>
# </td></tr>
# <tr>
# <td colspan="5">Dedicated Falcon 9 launch to put four Astranis MicroGEO communications satellites into service in 2023.<sup class="reference" id="cite_ref-astranis-microgeo-f9_364-1"><a href="#cite_note-astranis-microgeo-f9-364">[355]</a></sup> The MicroGEOs will be launched to a custom geostationary orbit, with the four satellites individually conducting on-orbit maneuvers to inject themselves into their orbital slots. However, it is unclear whether this will be a direct to <a href="/wiki/Geostationary_orbit" title="Geostationary orbit">geostationary orbit</a> insertion, or an optimized <a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">geostationary transfer orbit</a>. The four spacecraft will be mounted to a standard adapter ring, known as an <a href="/wiki/EELV_Secondary_Payload_Adapter" title="EELV Secondary Payload Adapter">ESPA-Grande</a>, for ease of deployment.
# </td></tr>
# <tr>
# <td rowspan="2">Mid 2024<sup class="reference" id="cite_ref-365"><a href="#cite_note-365">[356]</a></sup><sup class="reference" id="cite_ref-366"><a href="#cite_note-366">[357]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Arctic_Satellite_Broadband_Mission" title="Arctic Satellite Broadband Mission">ASBM 1</a> (<a class="mw-redirect" href="/wiki/Global_Xpress" title="Global Xpress">GX</a> 10A),<sup class="reference" id="cite_ref-367"><a href="#cite_note-367">[358]</a></sup> <a class="mw-redirect" href="/wiki/Arctic_Satellite_Broadband_Mission" title="Arctic Satellite Broadband Mission">ASBM 2</a> (<a class="mw-redirect" href="/wiki/Global_Xpress" title="Global Xpress">GX</a> 10B)
# </td>
# <td><a href="/wiki/Highly_elliptical_orbit" title="Highly elliptical orbit">HEO</a>
# </td>
# <td><a href="/wiki/Norwegian_Space_Agency" title="Norwegian Space Agency">Space Norway</a> / <a href="/wiki/Inmarsat" title="Inmarsat">Inmarsat</a>
# </td></tr>
# <tr>
# <td colspan="5"><a href="/wiki/Norwegian_Space_Agency" title="Norwegian Space Agency">Space Norway</a> will launch 2 satellites of the <a class="mw-redirect" href="/wiki/Arctic_Satellite_Broadband_Mission" title="Arctic Satellite Broadband Mission">Arctic Satellite Broadband Mission</a> (ASBM) system into highly elliptical orbits (apogee: 43,509 km (27,035 mi), perigee: 8,089 km (5,026 mi), 63.4° inclination)<sup class="reference" id="cite_ref-368"><a href="#cite_note-368">[359]</a></sup> to provide communication coverage to high latitudes not served by geosynchronous satellites.<sup class="reference" id="cite_ref-369"><a href="#cite_note-369">[360]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">8 July 2024<sup class="reference" id="cite_ref-370"><a href="#cite_note-370">[361]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/T%C3%BCrksat_6A" title="Türksat 6A">Türksat 6A</a><sup class="reference" id="cite_ref-371"><a href="#cite_note-371">[362]</a></sup>
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a href="/wiki/T%C3%BCrksat_(company)" title="Türksat (company)">Türksat</a>
# </td></tr>
# <tr>
# <td colspan="5">First domestically produced Turkish communications satellite.
# </td></tr>
# <tr>
# <td rowspan="2">July 2024<sup class="reference" id="cite_ref-Galileo_341-1"><a href="#cite_note-Galileo-341">[332]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td>TBD
# </td>
# <td>2× <a href="/wiki/Galileo_(satellite_navigation)" title="Galileo (satellite navigation)">Galileo</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Medium_Earth_Orbit" title="Medium Earth Orbit">MEO</a>
# </td>
# <td><a href="/wiki/European_Space_Agency" title="European Space Agency">ESA</a>
# </td></tr>
# <tr>
# <td colspan="5">Second launch of Galileo satellites.
# </td></tr>
# <tr>
# <td rowspan="2">July 2024
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a> or <a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>
# </td>
# <td><i><a href="/wiki/List_of_spaceflight_launches_in_January%E2%80%93June_2024#SpXTransporter11" title="List of spaceflight launches in January–June 2024">Transporter-11</a></i>, SmallSat Rideshare<sup class="reference" id="cite_ref-spacex-smallsat_307-2"><a href="#cite_note-spacex-smallsat-307">[298]</a></sup>
# </td>
# <td><a href="/wiki/Sun-synchronous_orbit" title="Sun-synchronous orbit">SSO</a>
# </td>
# <td>Various
# </td></tr>
# <tr>
# <td colspan="5">Dedicated SmallSat Rideshare mission to sun-synchronous orbit.
# </td></tr>
# <tr>
# <td rowspan="2">Mid August 2024<sup class="reference" id="cite_ref-372"><a href="#cite_note-372">[363]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a> ♺
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/SpaceX_Crew-9" title="SpaceX Crew-9">Crew-9</a><sup class="reference" id="cite_ref-NASACREW7-9_189-2"><a href="#cite_note-NASACREW7-9-189">[181]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a class="mw-redirect" href="/wiki/ISS_Crew_Transportation_Services" title="ISS Crew Transportation Services">CTS</a>)<sup class="reference" id="cite_ref-CCD6_85-5"><a href="#cite_note-CCD6-85">[77]</a></sup>
# </td></tr>
# <tr>
# <td colspan="5">After first six <a class="mw-redirect" href="/wiki/Crew_Dragon" title="Crew Dragon">Crew Dragon</a> launches of NASA <a class="mw-redirect" href="/wiki/Commercial_Crew_Development" title="Commercial Crew Development">USCV</a> award, a further three missions for SpaceX were announced on 3 December 2021. These launches carry up to four astronauts and 100 kg (220 lb) of cargo to the ISS as well as feature a lifeboat function to evacuate astronauts from ISS in case of an emergency.<sup class="reference" id="cite_ref-CCD6_85-6"><a href="#cite_note-CCD6-85">[77]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">H2 2024<sup class="reference" id="cite_ref-373"><a href="#cite_note-373">[364]</a></sup><sup class="reference" id="cite_ref-374"><a href="#cite_note-374">[365]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">KSC</a>,<br/><a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/Polaris_Dawn" title="Polaris Dawn">Polaris Dawn</a><sup class="reference" id="cite_ref-375"><a href="#cite_note-375">[366]</a></sup><br/>(<a href="/wiki/Crew_Dragon_Resilience" title="Crew Dragon Resilience">Crew Dragon C207.3 <i>Resilience</i></a> ♺ )
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Jared_Isaacman" title="Jared Isaacman">Jared Isaacman</a> / <a href="/wiki/Polaris_program" title="Polaris program">Polaris Program</a>
# </td></tr>
# <tr>
# <td colspan="5">First of two <a href="/wiki/SpaceX_Dragon_2" title="SpaceX Dragon 2">Crew Dragon</a> missions for the Polaris Program. Crew will consist of <a href="/wiki/Jared_Isaacman" title="Jared Isaacman">Jared Isaacman</a>, <a href="/wiki/Scott_Poteet" title="Scott Poteet">Scott Poteet</a>, <a href="/wiki/Sarah_Gillis" title="Sarah Gillis">Sarah Gillis</a> and <a href="/wiki/Anna_Menon" title="Anna Menon">Anna Menon</a> and will spend up to five days in orbit. Flying higher than any crewed Earth orbiting spacecraft has ever flown, Polaris Dawn will conduct research with the aim of better understanding the effects of spaceflight and space radiation on human health. At approximately 500 kilometers above the Earth, the crew will attempt the first-ever commercial extravehicular activity (EVA) with SpaceX-designed EVA spacesuits, derived from the existing intravehicular (IVA) suit.
# </td></tr>
# <tr>
# <td rowspan="2">H2 2024<sup class="reference" id="cite_ref-CKH_376-0"><a href="#cite_note-CKH-376">[367]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/Astra_1P" title="Astra 1P">Astra 1P</a>/SES-24<sup class="reference" id="cite_ref-CKH_376-1"><a href="#cite_note-CKH-376">[367]</a></sup>
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td></tr>
# <tr>
# <td colspan="5">Will serve major broadcasters across Europe.
# </td></tr>
# <tr>
# <td rowspan="2">H2 2024<sup class="reference" id="cite_ref-377"><a href="#cite_note-377">[368]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a> / <a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/Spainsat_NG" title="Spainsat NG">Spainsat-NG I</a><sup class="reference" id="cite_ref-hisdesat-20221107_378-0"><a href="#cite_note-hisdesat-20221107-378">[369]</a></sup>
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a href="/wiki/Hisdesat" title="Hisdesat">Hisdesat</a>
# </td></tr>
# <tr>
# <td colspan="5">Communications satellite built on the <a href="/wiki/Eurostar_(satellite_bus)" title="Eurostar (satellite bus)">Eurostar-Neo</a> platform, to be utilized by the Spanish government and its allies.<sup class="reference" id="cite_ref-:7_379-0"><a href="#cite_note-:7-379">[370]</a></sup> First of two launches for the Spainsat-NG program.
# </td></tr>
# <tr>
# <td rowspan="2">September 2024<sup class="reference" id="cite_ref-DoD28222_380-0"><a href="#cite_note-DoD28222-380">[371]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency#Launches" title="Space Development Agency">SDA Tranche 1 Tracking layer T1TL-B</a><sup class="reference" id="cite_ref-SSCA12_381-0"><a href="#cite_note-SSCA12-381">[372]</a></sup>
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr>
# <tr>
# <td rowspan="2">Late Q3 / Early Q4 2024<sup class="reference" id="cite_ref-382"><a href="#cite_note-382">[373]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">KSC</a>,<br/><a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Blue_Ghost" title="Blue Ghost">Blue Ghost</a> M1<sup class="reference" id="cite_ref-383"><a href="#cite_note-383">[374]</a></sup><sup class="reference" id="cite_ref-384"><a href="#cite_note-384">[375]</a></sup>
# </td>
# <td><a href="/wiki/Trans-lunar_injection" title="Trans-lunar injection">TLI</a>
# </td>
# <td><a href="/wiki/Firefly_Aerospace" title="Firefly Aerospace">Firefly Aerospace</a><br/>NASA (<a href="/wiki/Commercial_Lunar_Payload_Services" title="Commercial Lunar Payload Services">CLPS</a>)
# </td></tr>
# <tr>
# <td colspan="5"><a href="/wiki/Firefly_Aerospace" title="Firefly Aerospace">Firefly Aerospace</a> has selected <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>'s Falcon 9 rocket to deliver the Blue Ghost lunar lander to the lunar surface.<sup class="reference" id="cite_ref-385"><a href="#cite_note-385">[376]</a></sup> Blue Ghost will carry 10 payloads for NASA's <a href="/wiki/Commercial_Lunar_Payload_Services" title="Commercial Lunar Payload Services">Commercial Lunar Payload Services</a> task order 19D mission along with other separately contracted payloads.<sup class="reference" id="cite_ref-386"><a href="#cite_note-386">[377]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">8 October 2024<sup class="reference" id="cite_ref-sn-20221020_157-1"><a href="#cite_note-sn-20221020-157">[149]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCSFS</a>, <a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/Hera_(space_mission)" title="Hera (space mission)">Hera</a> with Juventas and Milani
# </td>
# <td><a href="/wiki/Heliocentric_orbit" title="Heliocentric orbit">Heliocentric</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/ESA" title="ESA">ESA</a>
# </td></tr>
# <tr>
# <td colspan="5">Hera is a space mission in development at the <a href="/wiki/European_Space_Agency" title="European Space Agency">European Space Agency</a> in its Space Safety program. Its primary objective is to study the <a href="/wiki/65803_Didymos" title="65803 Didymos">Didymos binary asteroid system</a> that was impacted by <a href="/wiki/Double_Asteroid_Redirection_Test" title="Double Asteroid Redirection Test">DART</a> and contribute to validation of the <a href="/wiki/Kinetic_energy" title="Kinetic energy">kinetic</a> impact method to deviate a <a href="/wiki/Near-Earth_object" title="Near-Earth object">near-Earth asteroid</a> in a colliding trajectory with Earth. It will measure the size and the morphology of the crater created by and momentum transferred by an artificial projectile impacting an asteroid, which will allow measuring the efficiency of the deflection produced by the impact. It will also carry two <a href="/wiki/Small_satellite" title="Small satellite">nano-satellite</a> CubeSats, called <i>Milani</i> and <i>Juventas</i>.
# </td></tr>
# <tr>
# <td rowspan="4">10 October 2024<sup class="reference" id="cite_ref-387"><a href="#cite_note-387">[378]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_Heavy" title="Falcon Heavy">Falcon Heavy B5</a><br/><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">B10xx (core)</a>
# </td>
# <td rowspan="3"><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">KSC</a>,<br/><a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td rowspan="3"><a href="/wiki/Europa_Clipper" title="Europa Clipper">Europa Clipper</a>
# </td>
# <td rowspan="3"><a href="/wiki/Heliocentric_orbit" title="Heliocentric orbit">Heliocentric</a>
# </td>
# <td rowspan="3"><a href="/wiki/NASA" title="NASA">NASA</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1064" title="List of Falcon 9 first-stage boosters">B1064.6 ♺ (side)</a><sup class="reference" id="cite_ref-arstechpsyche20230829_388-0"><a href="#cite_note-arstechpsyche20230829-388">[379]</a></sup>
# </td></tr>
# <tr>
# <td><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1065" title="List of Falcon 9 first-stage boosters">B1065.6 ♺ (side)</a><sup class="reference" id="cite_ref-arstechpsyche20230829_388-1"><a href="#cite_note-arstechpsyche20230829-388">[379]</a></sup>
# </td></tr>
# <tr>
# <td colspan="5"><a href="/wiki/Europa_Clipper" title="Europa Clipper">Europa Clipper</a> will conduct a detailed survey of <a href="/wiki/Europa_(moon)" title="Europa (moon)">Europa</a> and use a sophisticated suite of science instruments to investigate whether the icy moon has conditions suitable for life. Key mission objectives are to produce high-resolution images of Europa's surface, determine its composition, look for signs of recent or ongoing geological activity, measure the thickness of the moon's icy shell, search for subsurface lakes, and determine the depth and salinity of Europa's ocean.<sup class="reference" id="cite_ref-NASA_EC_L_389-0"><a href="#cite_note-NASA_EC_L-389">[380]</a></sup> The mission will fly past Mars and Earth before arriving at Jupiter in April 2030.<sup class="reference" id="cite_ref-390"><a href="#cite_note-390">[381]</a></sup><sup class="reference" id="cite_ref-391"><a href="#cite_note-391">[382]</a></sup> The side boosters and the center core will all be expended.
# </td></tr>
# <tr>
# <td rowspan="2">October 2024<sup class="reference" id="cite_ref-spacex-smallsat_307-3"><a href="#cite_note-spacex-smallsat-307">[298]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a> or <a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CC</a>
# </td>
# <td><a href="/wiki/List_of_spaceflight_launches_in_July%E2%80%93December_2024#SpXTransporter12" title="List of spaceflight launches in July–December 2024"><i>Transporter-12</i></a>, SmallSat Rideshare
# </td>
# <td><a href="/wiki/Sun-synchronous_orbit" title="Sun-synchronous orbit">SSO</a>
# </td>
# <td>Various
# </td></tr>
# <tr>
# <td colspan="5">Dedicated SmallSat Rideshare mission to sun-synchronous orbit.
# </td></tr>
# <tr>
# <td rowspan="2">October 2024<sup class="reference" id="cite_ref-DoD28222_380-1"><a href="#cite_note-DoD28222-380">[371]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency#Launches" title="Space Development Agency">SDA Tranche 1 Tracking layer T1TL-C</a><sup class="reference" id="cite_ref-SSCA12_381-1"><a href="#cite_note-SSCA12-381">[372]</a></sup>
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr>
# <tr>
# <td rowspan="2">October 2024<sup class="reference" id="cite_ref-392"><a href="#cite_note-392">[383]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">KSC</a>,<br/><a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Axiom_Mission_4" title="Axiom Mission 4">Ax-4</a><sup class="reference" id="cite_ref-axiom_132-2"><a href="#cite_note-axiom-132">[124]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/Axiom_Space" title="Axiom Space">Axiom Space</a>
# </td></tr>
# <tr>
# <td colspan="5">Contract for 3 additional missions was signed in June 2021.
# </td></tr>
# <tr>
# <td rowspan="2">November 2024<sup class="reference" id="cite_ref-393"><a href="#cite_note-393">[384]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_Heavy" title="Falcon Heavy">Falcon Heavy B5</a>
# </td>
# <td><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">KSC</a>,<br/><a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Griffin_Mission_1" title="Griffin Mission 1">Griffin Mission 1</a><sup class="reference" id="cite_ref-394"><a href="#cite_note-394">[385]</a></sup>
# </td>
# <td><a href="/wiki/Trans-lunar_injection" title="Trans-lunar injection">TLI</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Astrobotic" title="Astrobotic">Astrobotic</a><br/>NASA (<a href="/wiki/Artemis_program" title="Artemis program">Artemis</a>)
# </td></tr>
# <tr>
# <td colspan="5">Astrobotic's <a class="mw-redirect" href="/wiki/Griffin_(spacecraft)" title="Griffin (spacecraft)">Griffin lunar lander</a> was expected to deliver NASA's <i><a href="/wiki/VIPER_(rover)" title="VIPER (rover)">VIPER</a></i> spacecraft to the <a href="/wiki/Lunar_south_pole" title="Lunar south pole">lunar south pole</a>, but this is now extremely unlikely.<sup class="reference" id="cite_ref-395"><a href="#cite_note-395">[386]</a></sup> Booster recovery method is unconfirmed, but could possibly feature the first Falcon Heavy center core recovery attempt since <a class="mw-redirect" href="/wiki/STP-2" title="STP-2">STP-2</a>.<sup class="reference" id="cite_ref-396"><a href="#cite_note-396">[387]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">November 2024
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a> or <a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>
# </td>
# <td><i><a href="/wiki/List_of_spaceflight_launches_in_July%E2%80%93December_2024#SpXBandwagon2" title="List of spaceflight launches in July–December 2024">Bandwagon-2</a></i>, SmallSat Rideshare<sup class="reference" id="cite_ref-spacex-smallsat_307-4"><a href="#cite_note-spacex-smallsat-307">[298]</a></sup><sup class="reference" id="cite_ref-BandW_330-1"><a href="#cite_note-BandW-330">[321]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td>Various
# </td></tr>
# <tr>
# <td colspan="5">Dedicated SmallSat Rideshare mission to 45 degree inclination 550–600 km altitude.
# </td></tr>
# <tr>
# <td rowspan="2">November 2024<sup class="reference" id="cite_ref-DoD28222_380-2"><a href="#cite_note-DoD28222-380">[371]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency#Launches" title="Space Development Agency">SDA Tranche 1 Tracking layer T1TL-D</a><sup class="reference" id="cite_ref-SSCA12_381-2"><a href="#cite_note-SSCA12-381">[372]</a></sup>
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr>
# <tr>
# <td rowspan="2">November 2024
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a> or <a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>
# </td>
# <td>425 Project SAR satellite flight 3<sup class="reference" id="cite_ref-yonhap8124_397-0"><a href="#cite_note-yonhap8124-397">[388]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>?
# </td>
# <td><a href="/wiki/Republic_of_Korea_Armed_Forces" title="Republic of Korea Armed Forces">Republic of Korea Armed Forces</a>
# </td></tr>
# <tr>
# <td colspan="5">A military satellite of South Korea with a mass of ~800 kg. Expected to be a part of Bandwagon-2.<sup class="reference" id="cite_ref-398"><a href="#cite_note-398">[389]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">December 2024<sup class="reference" id="cite_ref-DoD28222_380-3"><a href="#cite_note-DoD28222-380">[371]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency#Launches" title="Space Development Agency">SDA Tranche 1 Tracking layer T1TL-E</a><sup class="reference" id="cite_ref-SSCA12_381-3"><a href="#cite_note-SSCA12-381">[372]</a></sup>
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr>
# <tr>
# <td rowspan="2">Q4 2024<sup class="reference" id="cite_ref-DoD28222_380-4"><a href="#cite_note-DoD28222-380">[371]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">VSFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency#Launches" title="Space Development Agency">SDA Tranche 1 Transport layer T1TR-C</a><sup class="reference" id="cite_ref-SSCA12_381-4"><a href="#cite_note-SSCA12-381">[372]</a></sup>
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr>
# <tr>
# <td rowspan="2">Q4 2024<sup class="reference" id="cite_ref-sn-20240213_399-0"><a href="#cite_note-sn-20240213-399">[390]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">KSC</a>,<br/><a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a><sup class="reference" id="cite_ref-400"><a href="#cite_note-400">[391]</a></sup>
# </td>
# <td><a class="mw-redirect" href="/wiki/IM-2" title="IM-2">IM-2</a> <i><a class="mw-redirect" href="/wiki/Nova-C" title="Nova-C">Nova-C</a></i> lunar lander<br/><a href="/wiki/SHERPA_(space_tug)" title="SHERPA (space tug)">Sherpa-ES</a>
# </td>
# <td><a href="/wiki/Trans-lunar_injection" title="Trans-lunar injection">TLI</a>
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Lunar_Payload_Services" title="Commercial Lunar Payload Services">CLPS</a>)<br/><a href="/wiki/Intuitive_Machines" title="Intuitive Machines">Intuitive Machines</a><br/><a href="/wiki/Spaceflight,_Inc." title="Spaceflight, Inc.">Spaceflight, Inc.</a>
# </td></tr>
# <tr>
# <td colspan="5">Intuitive Machines is sending its second lander aboard a SpaceX Falcon 9, with a projected launch time frame in late 2024. In February 2024, Intuitive Machines has completed its first lander mission via SpaceX, which is also hosting payloads for other private companies seeking to make lunar landfall under NASA's Commercial Lunar Payload Services program. NASA's <a href="/wiki/PRIME-1" title="PRIME-1">PRIME-1</a> is expected to be included.<sup class="reference" id="cite_ref-401"><a href="#cite_note-401">[392]</a></sup> The Sherpa-ES <i>Go Beyond</i> orbital transfer vehicle will deploy rideshare payloads to trans-lunar orbit, low-lunar orbit and beyond to GEO.<sup class="reference" id="cite_ref-402"><a href="#cite_note-402">[393]</a></sup><sup class="reference" id="cite_ref-403"><a href="#cite_note-403">[394]</a></sup><sup class="reference" id="cite_ref-404"><a href="#cite_note-404">[395]</a></sup> NASA's <a href="/wiki/Lunar_Trailblazer" title="Lunar Trailblazer">Lunar Trailblazer</a> mission will fly as a secondary payload on this mission.<sup class="reference" id="cite_ref-405"><a href="#cite_note-405">[396]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">Q4 2024<sup class="reference" id="cite_ref-406"><a href="#cite_note-406">[397]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/Koreasat" title="Koreasat">Koreasat</a> 6A<sup class="reference" id="cite_ref-407"><a href="#cite_note-407">[398]</a></sup>
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a href="/wiki/KT_Corporation" title="KT Corporation">KT Sat</a>
# </td></tr>
# <tr>
# <td colspan="5">South Korean communications satellite built on the <a href="/wiki/Spacebus" title="Spacebus">Spacebus-4000B2</a> platform. To be positioned at 116° East.<sup class="reference" id="cite_ref-408"><a href="#cite_note-408">[399]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">H2 2024<sup class="reference" id="cite_ref-nextSFupcoming_340-5"><a href="#cite_note-nextSFupcoming-340">[331]</a></sup><sup class="reference" id="cite_ref-SFPR9321_359-1"><a href="#cite_note-SFPR9321-359">[350]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a><sup class="reference" id="cite_ref-ussf36config_360-1"><a href="#cite_note-ussf36config-360">[351]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a><sup class="reference" id="cite_ref-ussf36location_409-0"><a href="#cite_note-ussf36location-409">[400]</a></sup>
# </td>
# <td>USSF-36
# </td>
# <td class="no table-no2" data-sort-value="" style="background: #DDF; vertical-align: middle; text-align: center;"><abbr title="To be announced">TBA</abbr>
# </td>
# <td><a href="/wiki/United_States_Space_Force" title="United States Space Force">USSF</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2021.<sup class="reference" id="cite_ref-defense.gov_361-1"><a href="#cite_note-defense.gov-361">[352]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">H2 2024<sup class="reference" id="cite_ref-O3b_Nov23_410-0"><a href="#cite_note-O3b_Nov23-410">[401]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/O3b_mPOWER" title="O3b mPOWER">O3b mPOWER</a> 7 &amp; 8
# </td>
# <td><a href="/wiki/Medium_Earth_orbit" title="Medium Earth orbit">MEO</a>
# </td>
# <td><a href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td></tr>
# <tr>
# <td colspan="5">In August 2020, SES expanded the O3b mPOWER contract with two additional launches, raising the number of satellites from 7 to 11 satellites at nearly 2 tons each.<sup class="reference" id="cite_ref-411"><a href="#cite_note-411">[402]</a></sup><sup class="reference" id="cite_ref-businesswire.com_412-0"><a href="#cite_note-businesswire.com-412">[403]</a></sup> In October 2023 the mission was delayed to the second half of 2024 due to electrical issues discovered in the first four satellites of the constellation.<sup class="reference" id="cite_ref-O3b_Nov23_410-1"><a href="#cite_note-O3b_Nov23-410">[401]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">H2 2024<sup class="reference" id="cite_ref-shephard14224_413-0"><a href="#cite_note-shephard14224-413">[404]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a> ♺<sup class="reference" id="cite_ref-worldviewlegion_342-2"><a href="#cite_note-worldviewlegion-342">[333]</a></sup><sup class="reference" id="cite_ref-WorldView-Legion_1,_...,_6_414-0"><a href="#cite_note-WorldView-Legion_1,_...,_6-414">[405]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCSFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a><sup class="reference" id="cite_ref-sfn_ls_338-1"><a href="#cite_note-sfn_ls-338">[329]</a></sup>
# </td>
# <td><a href="/wiki/DigitalGlobe#WorldView_Legion" title="DigitalGlobe">WorldView Legion 3-4</a> Mission 2 (2 sats)<sup class="reference" id="cite_ref-spacenews.com_415-0"><a href="#cite_note-spacenews.com-415">[406]</a></sup><sup class="reference" id="cite_ref-SN240423_416-0"><a href="#cite_note-SN240423-416">[407]</a></sup><sup class="reference" id="cite_ref-worldviewLegion10QSept22_417-0"><a href="#cite_note-worldviewLegion10QSept22-417">[408]</a></sup>
# </td>
# <td><a href="/wiki/Sun-synchronous_orbit" title="Sun-synchronous orbit">SSO</a>
# </td>
# <td><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">Maxar Technologies</a>
# </td></tr>
# <tr>
# <td colspan="5"><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">Maxar Technologies</a> built satellites.
# </td></tr>
# <tr>
# <td rowspan="2">H2 2024<sup class="reference" id="cite_ref-shephard14224_413-1"><a href="#cite_note-shephard14224-413">[404]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a> ♺<sup class="reference" id="cite_ref-worldviewlegion_342-3"><a href="#cite_note-worldviewlegion-342">[333]</a></sup><sup class="reference" id="cite_ref-WorldView-Legion_1,_...,_6_414-1"><a href="#cite_note-WorldView-Legion_1,_...,_6-414">[405]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a><sup class="reference" id="cite_ref-nextSFupcoming_340-6"><a href="#cite_note-nextSFupcoming-340">[331]</a></sup>
# </td>
# <td><a href="/wiki/DigitalGlobe#WorldView_Legion" title="DigitalGlobe">WorldView Legion 5 &amp; 6</a> Mission 3 (2 sats)<sup class="reference" id="cite_ref-spacenews.com_415-1"><a href="#cite_note-spacenews.com-415">[406]</a></sup><sup class="reference" id="cite_ref-SN240423_416-1"><a href="#cite_note-SN240423-416">[407]</a></sup><sup class="reference" id="cite_ref-worldviewLegion10QSept22_417-1"><a href="#cite_note-worldviewLegion10QSept22-417">[408]</a></sup>
# </td>
# <td><a href="/wiki/Sun-synchronous_orbit" title="Sun-synchronous orbit">SSO</a>
# </td>
# <td><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">Maxar Technologies</a>
# </td></tr>
# <tr>
# <td colspan="5"><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">Maxar Technologies</a> built satellites.
# </td></tr>
# <tr>
# <td rowspan="2">2024<sup class="reference" id="cite_ref-nextSFupcoming_340-7"><a href="#cite_note-nextSFupcoming-340">[331]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a> ♺
# </td>
# <td><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">KSC</a>,<br/><a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/Doge-1" title="Doge-1">DOGE-1</a> <span style="color:darkgreen"><abbr title="It is not yet clear whether this will fly as a primary payload, a secondary payload or on a dedicated rideshare mission">Possible rideshare</abbr></span>
# </td>
# <td><a href="/wiki/Trans-lunar_injection" title="Trans-lunar injection">TLI</a>
# </td>
# <td>Geometric Energy
# </td></tr>
# <tr>
# <td colspan="5">Originally expected to be a secondary rideshare payload on <a href="/wiki/IM-1" title="IM-1">IM-1</a> mission but the 40 kg was later postponed to a later date due to incomplete radio and launch requirements.&gt;<sup class="reference" id="cite_ref-418"><a href="#cite_note-418">[409]</a></sup><sup class="noprint Inline-Template noprint Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:No_original_research#Primary,_secondary_and_tertiary_sources" title="Wikipedia:No original research"><span title="This claim needs references to reliable secondary sources. (February 2024)">non-primary source needed</span></a></i>]</sup>
# </td></tr>
# <tr>
# <td rowspan="2">2024<sup class="reference" id="cite_ref-ispr25122_419-0"><a href="#cite_note-ispr25122-419">[410]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td>Unknown
# </td>
# <td><a href="/wiki/Ispace_(Japanese_company)" title="Ispace (Japanese company)">ispace</a> 2nd lunar lander<sup class="reference" id="cite_ref-420"><a href="#cite_note-420">[411]</a></sup>
# </td>
# <td><a class="mw-redirect" href="/wiki/Trans_Lunar_Injection" title="Trans Lunar Injection">TLI</a>
# </td>
# <td><a href="/wiki/Ispace_(Japanese_company)" title="Ispace (Japanese company)">ispace</a>
# </td></tr>
# <tr>
# <td colspan="5">Second lunar lander built by Japanese company <a href="/wiki/Ispace_(Japanese_company)" title="Ispace (Japanese company)">ispace</a>.
# </td></tr>
# <tr>
# <td rowspan="2">2024<sup class="reference" id="cite_ref-421"><a href="#cite_note-421">[412]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a> / <a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/Thuraya#Satellites" title="Thuraya">Thuraya 4-NGS</a>
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a href="/wiki/Thuraya" title="Thuraya">Thuraya</a>
# </td></tr>
# <tr>
# <td colspan="5">Planned replacement for Thuraya 2.<sup class="reference" id="cite_ref-422"><a href="#cite_note-422">[413]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">2024
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a> / <a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a href="/wiki/Cygnus_NG-21" title="Cygnus NG-21">CRS NG-21</a> (<a href="/wiki/Cygnus_(spacecraft)" title="Cygnus (spacecraft)">Cygnus (enhanced)</a>)<sup class="reference" id="cite_ref-NG_RepAnt_283-1"><a href="#cite_note-NG_RepAnt-283">[274]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/Northrop_Grumman" title="Northrop Grumman">Northrop Grumman</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td></tr>
# <tr>
# <td colspan="5">Second of three launches Northrop Grumman acquired from SpaceX while a replacement engine is developed for its Antares rocket.
# </td></tr>
# <tr>
# <td rowspan="2">2024
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a> / <a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Cygnus_NG-22" title="Cygnus NG-22">CRS NG-22</a> (<a href="/wiki/Cygnus_(spacecraft)" title="Cygnus (spacecraft)">Cygnus (enhanced)</a>)<sup class="reference" id="cite_ref-NG_RepAnt_283-2"><a href="#cite_note-NG_RepAnt-283">[274]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/Northrop_Grumman" title="Northrop Grumman">Northrop Grumman</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td></tr>
# <tr>
# <td colspan="5">Third of three launches Northrop Grumman acquired from SpaceX while a replacement engine is developed for its Antares rocket.
# </td></tr>
# <tr>
# <td rowspan="2">2024
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td>Unknown
# </td>
# <td>Reentry demonstration capsule <span style="color:darkgreen"><abbr title="It is not yet clear whether this will fly as a primary payload, a secondary payload or on a dedicated rideshare mission">Possible rideshare</abbr></span>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/The_Exploration_Company" title="The Exploration Company">The Exploration Company</a>
# </td></tr>
# <tr>
# <td colspan="5">1600 kg 2.5 metre diameter reduced scale test of a reentry capsule, the full-scale version Nyx (4 metre diameter 8000 kg) is planned to deliver payloads to the ISS and return them back to Earth.<sup class="reference" id="cite_ref-423"><a href="#cite_note-423">[414]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">2024?
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9 B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral" title="Cape Canaveral">CC</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>/<a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td>USSF-31<sup class="reference" id="cite_ref-SSCA12_381-5"><a href="#cite_note-SSCA12-381">[372]</a></sup>
# </td>
# <td class="no table-no2" data-sort-value="" style="background: #DDF; vertical-align: middle; text-align: center;"><abbr title="To be announced">TBA</abbr>
# </td>
# <td><a href="/wiki/United_States_Space_Force" title="United States Space Force">USSF</a>
# </td></tr>
# <tr>
# <td colspan="5">Classified mission, part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr></tbody></table>

# %% [markdown]
# You should able to see the columns names embedded in the table header elements `<th>` as follows:

# %% [markdown]
# ```
# <tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11">[b]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12">[c]</a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# ```

# %% [markdown]
# Next, we just need to iterate through the `<th>` elements and apply the provided `extract_column_from_header()` to extract column name one by one

# %%
column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names
# Encontrar todas as tags th na primeira tabela
th_tags = first_launch_table.find_all('th')

# Iterar sobre cada tag th
for th in th_tags:
    # Extrair o nome da coluna usando a função fornecida
    name = extract_column_from_header(th)
    # Verificar se o nome não está vazio antes de adicioná-lo à lista
    if name is not None and len(name) > 0:
        column_names.append(name)

# %% [markdown]
# Check the extracted column names

# %%
print(column_names)
# Out:
# ['Date and time ( )', 'Launch site', 'Payload', 'Orbit', 'Customer']

# %% [markdown]
# ## TASK 3: Create a data frame by parsing the launch HTML tables

# %% [markdown]
# We will create an empty dictionary with keys from the extracted column names in the previous task. Later, this dictionary will be converted into a Pandas dataframe

# %%
launch_dict= dict.fromkeys(column_names)

# Remove an irrelvant column
del launch_dict['Date and time ( )']

# Let's initial the launch_dict with each value to be an empty list
launch_dict['Flight No.'] = []
launch_dict['Launch site'] = []
launch_dict['Payload'] = []
launch_dict['Payload mass'] = []
launch_dict['Orbit'] = []
launch_dict['Customer'] = []
launch_dict['Launch outcome'] = []
# Added some new columns
launch_dict['Version Booster']=[]
launch_dict['Booster landing']=[]
launch_dict['Date']=[]
launch_dict['Time']=[]

# %% [markdown]
# Next, we just need to fill up the `launch_dict` with launch records extracted from table rows.

# %% [markdown]
# Usually, HTML tables in Wiki pages are likely to contain unexpected annotations and other types of noises, such as reference links `B0004.1[8]`, missing values `N/A [e]`, inconsistent formatting, etc.

# %% [markdown]
# To simplify the parsing process, we have provided an incomplete code snippet below to help you to fill up the `launch_dict`. Please complete the following code snippet with TODOs or you can choose to write your own logic to parse all launch tables:

# %%
extracted_row = 0
# Extract each table 
for table_number, table in enumerate(soup.find_all('table', "wikitable plainrowheaders collapsible")):
    # get table row 
    for rows in table.find_all("tr"):
        # check to see if first table heading is as number corresponding to launch a number 
        if rows.th:
            if rows.th.string:
                flight_number = rows.th.string.strip()
                flag = flight_number.isdigit()
        else:
            flag = False
        # get table element 
        row = rows.find_all('td')
        # if it is number save cells in a dictionary 
        if flag:
            extracted_row += 1
            # Flight Number value
            # TODO: Append the flight_number into launch_dict with key `Flight No.`
            print(flight_number)
            datatimelist = date_time(row[0])
            
            # Date value
            # TODO: Append the date into launch_dict with key `Date`
            date = datatimelist[0].strip(',')
            print(date)
            
            # Time value
            # TODO: Append the time into launch_dict with key `Time`
            time = datatimelist[1]
            print(time)
              
            # Booster version
            # TODO: Append the bv into launch_dict with key `Version Booster`
            bv = booster_version(row[1])
            if not(bv):
                bv = row[1].a.string
            print(bv)
            
            # Launch Site
            # TODO: Append the bv into launch_dict with key `Launch Site`
            launch_site = row[2].a.string
            print(launch_site)
            
            # Payload
            # TODO: Append the payload into launch_dict with key `Payload`
            payload = row[3].a.string
            print(payload)
            
            # Payload Mass
            # TODO: Append the payload_mass into launch_dict with key `Payload mass`
            payload_mass = get_mass(row[4])
            print(payload)
            
            # Orbit
            # TODO: Append the orbit into launch_dict with key `Orbit`
            orbit = row[5].a.string
            print(orbit)
            
            # Customer
            # TODO: Append the customer into launch_dict with key `Customer`
            customer = None
            if row[6].a is not None:
                customer = row[6].a.string
            else:
                customer = row[6].string
            print(customer)
            
            # Launch outcome
            # TODO: Append the launch_outcome into launch_dict with key `Launch outcome`
            launch_outcome = list(row[7].strings)[0]
            print(launch_outcome)
            
            # Booster landing
            # TODO: Append the launch_outcome into launch_dict with key `Booster landing`
            booster_landing = landing_status(row[8])
            print(booster_landing)
# Out:
# 195
# 3 January 2023
# 14:56
# F9 B5B1060.15
# CCSFS
# None
# None
# SSO
# Various
#
# Success
#
# Success
# 196
# 10 January 2023
# 04:50
# F9 B5
# CCSFS
# OneWeb
# OneWeb
# Polar
# OneWeb
# Success
#
# Success
# 197
# 18 January 2023
# 12:24
# F9 B5
# CCSFS
# USA-343
# USA-343
# MEO
# USSF
# Success
#
# Success
# 198
# 19 January 2023
# 15:43
# F9 B5
# VSFB
# Starlink Group 2-4
# Starlink Group 2-4
# LEO
# SpaceX
# Success
#
# Success
# 199
# 26 January 2023
# 09:32
# F9 B5
# CCSFS
# Starlink Group 5-2
# Starlink Group 5-2
# LEO
# SpaceX
# Success
#
# Success
# 200
# 31 January 2023
# 16:15
# F9 B5B1071.7
# VSFB
# Starlink Group 2-6
# Starlink Group 2-6
# LEO
# SpaceX
# Success
#
# Success
# 201
# 2 February 2023
# 07:58
# F9 B5
# KSC
# Starlink Group 5-3
# Starlink Group 5-3
# LEO
# SpaceX
# Success
#
# Success
# 202
# 7 February 2023
# 01:32
# F9 B5B1073.6
# CCSFS
# Amazonas Nexus
# Amazonas Nexus
# GTO
# Hispasat
# Success
#
# Success
# 203
# 12 February 2023
# 05:10
# F9 B5B1062.12
# CCSFS
# Starlink Group 5-4
# Starlink Group 5-4
# LEO
# SpaceX
# Success
#
# Success
# 204
# 17 February 2023
# 19:12
# F9 B5B1063.9
# VSFB
# Starlink Group 2-5
# Starlink Group 2-5
# LEO
# SpaceX
# Success
#
# Success
# 205
# 18 February 2023
# 03:59
# F9 B5B1077.3
# CCSFS
# Inmarsat-6 F2
# Inmarsat-6 F2
# GTO
# Inmarsat
# Success
#
# Success
# 206
# 27 February 2023
# 23:13
# F9 B5B1076.3
# CCSFS
# Starlink Group 6-1
# Starlink Group 6-1
# LEO
# SpaceX
# Success
#
# Success
# 207
# 2 March 2023
# 05:34
# F9 B5
# KSC
# Crew-6
# Crew-6
# LEO
# NASA
# Success
#
# Success
# 208
# 3 March 2023
# 18:38
# F9 B5
# VSFB
# Starlink Group 2-7
# Starlink Group 2-7
# LEO
# SpaceX
# Success
#
# Success
# 209
# 9 March 2023
# 19:13
# F9 B5
# CCSFS
# OneWeb #17
# OneWeb #17
# LEO
# OneWeb
# Success
#
# Success
# 210
# 15 March 2023
# 00:30
# F9 B5B1073.7
# KSC
# SpaceX CRS-27
# SpaceX CRS-27
# LEO
# NASA
# Success
#
# Success
# 211
# 17 March 2023
# 19:26
# F9 B5
# VSFB
# Starlink Group 2-8
# Starlink Group 2-8
# LEO
# SpaceX
# Success
#
# Success
# 212
# 17 March 2023
# 23:38
# F9 B5
# CCSFS
# SES-18 and SES-19
# SES-18 and SES-19
# GTO
# SES
# Success
#
# Success
# 213
# 24 March 2023
# 15:43
# F9 B5
# CCSFS
# Starlink Group 5-5
# Starlink Group 5-5
# LEO
# SpaceX
# Success
#
# Success
# 214
# 29 March 2023
# 20:01
# F9 B5
# CCSFS
# Starlink Group 5-10
# Starlink Group 5-10
# LEO
# SpaceX
# Success
#
# Success
# 215
# 2 April 2023
# 14:29
# F9 B5
# VSFB
# Transport and Tracking Layer (Tranche 0A)
# Transport and Tracking Layer (Tranche 0A)
# LEO
# SDA
# Success
#
# Success
# 216
# 7 April 2023
# 04:30
# F9 B5
# CCSFS
# Intelsat 40e
# Intelsat 40e
# GTO
# Intelsat
# Success
#
# Success
# 217
# 15 April 2023
# 06:47
# F9 B5
# VSFB
# Transporter-7: (51 payloads Smallsat Rideshare)
# Transporter-7: (51 payloads Smallsat Rideshare)
# SSO
# Various
#
# Success
#
# Success
# 218
# 19 April 2023
# 14:31
# F9 B5
# CCSFS
# Starlink Group 6-2
# Starlink Group 6-2
# LEO
# SpaceX
# Success
#
# Success
# 219
# 27 April 2023
# 13:40
# F9 B5
# VSFB
# Starlink Group 3-5
# Starlink Group 3-5
# SSO
# SpaceX
# Success
#
# Success
# 220
# 28 April 2023
# 22:12
# F9 B5B1078.2
# CCSFS
# O3b mPOWER
# O3b mPOWER
# MEO
# SES
# Success
#
# Success
# 221
# 4 May 2023
# 07:31
# F9 B5B1069.7
# CCSFS
# Starlink Group 5-6
# Starlink Group 5-6
# LEO
# SpaceX
# Success
#
# Success
# 222
# 10 May 2023
# 20:09
# F9 B5B1075.3
# VSFB
# Starlink Group 2-9
# Starlink Group 2-9
# LEO
# SpaceX
# Success
#
# Success
# 223
# 14 May 2023
# 05:03
# F9 B5
# CCSFS
# Starlink Group 5-9
# Starlink Group 5-9
# LEO
# SpaceX
# Success
#
# Success
# 224
# 19 May 2023
# 06:19
# F9 B5
# CCSFS
# Starlink Group 6-3
# Starlink Group 6-3
# LEO
# SpaceX
# Success
#
# Success
# 225
# 20 May 2023
# 13:16
# F9 B5
# VSFB
# Iridium-NEXT
# Iridium-NEXT
# Polar
# Iridium
# Success
#
# Success
# 226
# 21 May 2023
# 21:37
# F9 B5
# KSC
# Ax-2
# Ax-2
# LEO
# Axiom Space
# Success
#
# Success
# 227
# 27 May 2023
# 04:30
# F9 B5
# CCSFS
# ArabSat 7B
# ArabSat 7B
# GTO
# Arabsat
# Success
#
# Success
# 228
# 31 May 2023
# 06:02
# F9 B5
# VSFB
# Starlink Group 2-10
# Starlink Group 2-10
# LEO
# SpaceX
# Success
#
# Success
# 229
# 4 June 2023
# 12:20
# F9 B5
# CCSFS
# Starlink Group 6-4
# Starlink Group 6-4
# LEO
# SpaceX
# Success
#
# Success
# 230
# 5 June 2023
# 15:47
# F9 B5B1077.5
# KSC
# SpaceX CRS-28
# SpaceX CRS-28
# LEO
# NASA
# Success
#
# Success
# 231
# 12 June 2023
# 07:10
# F9 B5
# CCSFS
# Starlink Group 5-11
# Starlink Group 5-11
# LEO
# SpaceX
# Success
#
# Success
# 232
# 12 June 2023
# 21:35
# F9 B5
# VSFB
# None
# None
# SSO
# Various
#
# Success
#
# Success
# 233
# 18 June 2023
# 22:21
# F9 B5B1067.12
# CCSFS
# SATRIA
# SATRIA
# GTO
# PT Pasifik Satelit Nusantara
# Success
#
# Success
# 234
# 22 June 2023
# 07:19
# F9 B5B1075.4
# VSFB
# Starlink Group 5-7
# Starlink Group 5-7
# LEO
# SpaceX
# Success
#
# Success
# 235
# 23 June 2023
# 15:35
# F9 B5
# CCSFS
# Starlink Group 5-12
# Starlink Group 5-12
# LEO
# SpaceX
# Success
#
# Success
# 236
# 1 July 2023
# 15:12
# F9 B5
# CCSFS
# Euclid
# Euclid
# None
# ESA
# Success
#
# Success
# 237
# 7 July 2023
# 19:29
# F9 B5B1063.12
# VSFB
# Starlink Group 5-13
# Starlink Group 5-13
# LEO
# SpaceX
# SDA
# LEO
# USSF
# Success
#
# Success
# 299
# 15 February 2024
# 06:05
# F9 B5
# KSC
# IM-1
# IM-1
# TLI
# NASA
# Success
#
# Success
# 300
# 15 February 2024
# 21:34
# F9 B5
# VSFB
# Starlink Group 7-14
# Starlink Group 7-14
# LEO
# SpaceX
# Success
#
# Success
# 301
# 20 February 2024
# 20:11
# F9 B5
# CCSFS
# Merah Putih 2 / Telkomsat HTS 113BT
# Merah Putih 2 / Telkomsat HTS 113BT
# GTO
# Telkom Indonesia
# Success
#
# Success
# 302
# 23 February 2024
# 04:11
# F9 B5
# VSFB
# Starlink Group 7-15
# Starlink Group 7-15
# LEO
# SpaceX
# Success
#
# Success
# 303
# 25 February 2024
# 22:06
# F9 B5
# CCSFS
# Starlink Group 6-39
# Starlink Group 6-39
# LEO
# SpaceX
# Success
#
# Success
# 304
# 29 February 2024
# 15:30
# F9 B5
# CCSFS
# Starlink Group 6-40
# Starlink Group 6-40
# LEO
# SpaceX
# Success
#
# Success
# 305
# 4 March 2024
# 03:53
# F9 B5
# KSC
# Crew-8
# Crew-8
# LEO
# NASA
# Success
#
# Success
# 306
# 4 March 2024
# 22:05
# F9 B5
# VSFB
# None
# None
# SSO
# Various
#
# Success
#
# Success
# 307
# 4 March 2024
# 23:56
# F9 B5
# CCSFS
# Starlink Group 6-41
# Starlink Group 6-41
# LEO
# SpaceX
# Success
#
# Success
# 308
# 10 March 2024
# 23:05
# F9 B5
# CCSFS
# Starlink Group 6-43
# Starlink Group 6-43
# LEO
# SpaceX
# Success
#
# Success
# 309
# 11 March 2024
# 04:09
# F9 B5
# VSFB
# Starlink Group 7-17
# Starlink Group 7-17
# LEO
# SpaceX
# Success
#
# Success
# 310
# 16 March 2024
# 00:21
# F9 B5
# KSC
# Starlink Group 6-44
# Starlink Group 6-44
# LEO
# SpaceX
# Success
#
# Success
# 311
# 19 March 2024
# 02:28
# F9 B5
# VSFB
# Starlink Group 7-16
# Starlink Group 7-16
# LEO
# SpaceX
# Success
#
# Success
# 312
# 21 March 2024
# 20:55
# F9 B5
# CCSFS
# SpaceX CRS-30
# SpaceX CRS-30
# LEO
# NASA
# Success
#
# Success
# 313
# 24 March 2024
# 03:09
# F9 B5
# KSC
# Starlink Group 6-42
# Starlink Group 6-42
# LEO
# SpaceX
# Success
#
# Success
# 314
# 25 March 2024
# 23:42
# F9 B5
# CCSFS
# Starlink Group 6-46
# Starlink Group 6-46
# LEO
# SpaceX
# Success
#
# Success
# 315
# 30 March 2024
# 21:52
# F9 B5
# KSC
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 47
#      43 print(launch_site)
#      45 # Payload
#      46 # TODO: Append the payload into launch_dict with key `Payload`
# ---> 47 payload = row[3].a.string
#      48 print(payload)
#      50 # Payload Mass
#      51 # TODO: Append the payload_mass into launch_dict with key `Payload mass`
#
# AttributeError: 'NoneType' object has no attribute 'string'

# %% [markdown]
# After you have fill in the parsed launch record values into `launch_dict`, you can create a dataframe from it.

# %%
df= pd.DataFrame({ key:pd.Series(value) for key, value in launch_dict.items() })

# %%
year = pd.to_datetime(spacex_df['static_fire_date_utc'].iloc[0]).year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 year = pd.to_datetime(spacex_df['static_fire_date_utc'].iloc[0]).year
#
# NameError: name 'spacex_df' is not defined

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section, but to make the answers consistent and in case you have difficulties finishing this lab.
#
# Following labs will be using a provided dataset to make each lab independent.

# %% [markdown]
# <code>df.to_csv('spacex_web_scraped.csv', index=False)</code>

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/yan-luo-96288783/">Yan Luo</a>

# %% [markdown]
# <a href="https://www.linkedin.com/in/nayefaboutayoun/">Nayef Abou Tayoun</a>

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description      |
# | ----------------- | ------- | ---------- | ----------------------- |
# | 2021-06-09        | 1.0     | Yan Luo    | Tasks updates           |
# | 2020-11-10        | 1.0     | Nayef      | Created the initial version |

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
